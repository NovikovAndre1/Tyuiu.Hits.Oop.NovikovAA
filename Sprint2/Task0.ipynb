// %% [markdown]
// <h1 style="color:DodgerBlue">Простое наследование</h1>

// %% [markdown]
// Простое наследование в C# позволяет создавать новые классы на основе существующих, наследуя их свойства и методы. Это мощный механизм для повторного использования кода и организации программ на основе иерархии классов. Давайте рассмотрим пример наследования с классами `Vehicle`, `Car` и `Motorcycle`.
//
// ### Шаг 1: Определение базового класса
//
// Сначала определим базовый класс `Vehicle`. Этот класс будет содержать общие свойства и методы, которые могут быть у всех транспортных средств.
//
// ```csharp
// public class Vehicle
// {
//     // Свойство для хранения марки транспортного средства
//     public string Make { get; set; }
//
//     // Свойство для хранения модели транспортного средства
//     public string Model { get; set; }
//
//     // Конструктор класса Vehicle
//     public Vehicle(string make, string model)
//     {
//         Make = make;
//         Model = model;
//     }
//
//     // Метод для отображения информации о транспортном средстве
//     public void DisplayInfo()
//     {
//         Console.WriteLine($"Производитель: {Make}, Модель: {Model}");
//     }
// }
// ```
//
// ### Шаг 2: Создание производных классов
//
// Теперь создадим два производных класса `Car` и `Motorcycle`, которые наследуют от базового класса `Vehicle`.
//
// #### Класс Car
//
// Класс `Car` добавит дополнительные свойства, специфичные для автомобилей, например, количество дверей.
//
// ```csharp
// public class Car : Vehicle
// {
//     // Свойство для хранения количества дверей
//     public int Doors { get; set; }
//
//     // Конструктор класса Car
//     public Car(string make, string model, int doors) : base(make, model)
//     {
//         Doors = doors;
//     }
//
//     // Переопределенный метод DisplayInfo для отображения информации о автомобиле
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Двери: {Doors}");
//     }
// }
// ```
//
// #### Класс Motorcycle
//
// Аналогично, класс `Motorcycle` может добавить свои специфические свойства, например, тип двигателя.
//
// ```csharp
// public class Motorcycle : Vehicle
// {
//     // Свойство для хранения типа двигателя
//     public string EngineType { get; set; }
//
//     // Конструктор класса Motorcycle
//     public Motorcycle(string make, string model, string engineType) : base(make, model)
//     {
//         EngineType = engineType;
//     }
//
//     // Переопределенный метод DisplayInfo для отображения информации о мотоцикле
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Вид двигателя: {EngineType}");
//     }
// }
// ```
//
// ### Шаг 3: Использование классов
//
// Теперь мы можем создать экземпляры наших классов и использовать их.
//
// ```csharp
// // Создаем объект класса Car
// Car myCar = new Car("Toyota", "Corolla", 4);
// myCar.DisplayInfo(); // Выводит информацию о автомобиле
//
// // Создаем объект класса Motorcycle
// Motorcycle myMotorcycle = new Motorcycle("Honda", "CBR600RR", "Inline Four");
// myMotorcycle.DisplayInfo(); // Выводит информацию о мотоцикле
//
//
// ```
//
// ### Объяснение кода
//
// - **Базовый класс `Vehicle`**: Определяет общую структуру для всех транспортных средств, включая свойства `Make` и `Model`, а также метод `DisplayInfo()` для вывода информации.
// - **Производные классы `Car` и `Motorcycle`**: Наследуют от `Vehicle` и добавляют собственные свойства (`Doors` для `Car` и `EngineType` для `Motorcycle`). Также переопределяют метод `DisplayInfo()` для вывода дополнительной информации.
// - **Использование классов**: В `Main` создаются экземпляры `Car` и `Motorcycle`, и вызывается метод `DisplayInfo()` для каждого из них, демонстрируя различие в информации, которую они выводят.
//
// Этот пример показывает, как можно использовать простое наследование в C# для создания иерархии классов, где каждый класс расширяет функциональность предка, сохраняя при этом возможность индивидуализации своих свойств и поведения.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Vehicle, Car и Motorcycle ниже в блоке:</h4>
//
// ----

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также простое наследование.

// %%
public class Animal
{
    // Свойство для хранения имени животного
    public string Name { get; set; }

    // Свойство для хранения возраста животного
    public int Age { get; set; }

    // Свойство для хранения вида животного (будет установлено производными классами)
    // Используем 'protected set', чтобы производные классы могли его устанавливать,
    // но извне класса оно было доступно только для чтения.
    public string Species { get; protected set; } 

    // Конструктор базового класса Animal
    public Animal(string name, int age)
    {
        Name = name;
        Age = age;
        Species = "Неизвестное животное"; // Значение по умолчанию
    }

    // Метод для отображения общей информации о животном
    // Метод виртуальный, чтобы его можно было переопределить в производных классах
    public virtual void DisplayInfo()
    {
        Console.WriteLine($"--- Информация о животном ({Species}) ---");
        Console.WriteLine($"Имя: {Name}");
        Console.WriteLine($"Возраст: {Age} лет");
    }

    // Метод для воспроизведения звука животного
    // Метод виртуальный, чтобы каждое животное могло издавать свой специфический звук
    public virtual void MakeSound()
    {
        Console.WriteLine($"{Name} издает общий животный звук.");
    }
}

// Шаг 2: Создание производных классов

// Класс Dog наследует от Animal
// Добавит дополнительные свойства, специфичные для собак, например, породу.
public class Dog : Animal
{
    // Свойство для хранения породы собаки
    public string Breed { get; set; }

    // Конструктор класса Dog
    public Dog(string name, int age, string breed) : base(name, age)
    {
        // Устанавливаем специфический вид для собак
        Species = "Собака";
        Breed = breed;
    }

    // Переопределенный метод DisplayInfo для отображения информации о собаке
    public override void DisplayInfo()
    {
        base.DisplayInfo(); // Вызываем метод базового класса для отображения общей информации
        Console.WriteLine($"Порода: {Breed}");
    }

    // Переопределенный метод MakeSound для собак
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} говорит: Гав! Гав!");
    }
}

// Класс Cat наследует от Animal
// Добавит дополнительные свойства, специфичные для кошек, например, цвет шерсти.
public class Cat : Animal
{
    // Свойство для хранения цвета шерсти кошки
    public string FurColor { get; set; }

    // Конструктор класса Cat
    public Cat(string name, int age, string furColor) : base(name, age)
    {
        // Устанавливаем специфический вид для кошек
        Species = "Кошка";
        FurColor = furColor;
    }

    // Переопределенный метод DisplayInfo для отображения информации о кошке
    public override void DisplayInfo()
    {
        base.DisplayInfo(); // Вызываем метод базового класса
        Console.WriteLine($"Цвет шерсти: {FurColor}");
    }

    // Переопределенный метод MakeSound для кошек
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} говорит: Мяу!");
    }
}

// Класс Bird наследует от Animal
// Добавит дополнительные свойства, специфичные для птиц, например, может ли летать.
public class Bird : Animal
{
    // Свойство для хранения информации о том, может ли птица летать
    public bool CanFly { get; set; }

    // Конструктор класса Bird
    public Bird(string name, int age, bool canFly) : base(name, age)
    {
        // Устанавливаем специфический вид для птиц
        Species = "Птица";
        CanFly = canFly;
    }

    // Переопределенный метод DisplayInfo для отображения информации о птице
    public override void DisplayInfo()
    {
        base.DisplayInfo(); // Вызываем метод базового класса
        Console.WriteLine($"Может летать: {(CanFly ? "Да" : "Нет")}");
    }

    // Переопределенный метод MakeSound для птиц
    public override void MakeSound()
    {
        Console.WriteLine($"{Name} говорит: Чирик-чирик!");
    }
}



        // Устанавливаем кодировку для корректного отображения кириллицы в консоли
        Console.OutputEncoding = System.Text.Encoding.UTF8;

        Console.WriteLine("--- Создание и использование животных ---");

        // Создаем объект класса Dog
        Dog myDog = new Dog("Бадди", 5, "Золотистый ретривер");
        myDog.DisplayInfo(); // Выводит информацию о собаке
        myDog.MakeSound();   // Собака издает звук
        Console.WriteLine("\n--------------------\n");

        // Создаем объект класса Cat
        Cat myCat = new Cat("Пушинка", 3, "Рыжий");
        myCat.DisplayInfo(); // Выводит информацию о кошке
        myCat.MakeSound();   // Кошка издает звук
        Console.WriteLine("\n--------------------\n");

        // Создаем объект класса Bird
        Bird myBird = new Bird("Кеша", 1, true);
        myBird.DisplayInfo(); // Выводит информацию о птице
        myBird.MakeSound();   // Птица издает звук
        Console.WriteLine("\n--------------------\n");

        // Можно также создать экземпляр базового класса (если он не абстрактный)
        Animal genericAnimal = new Animal("Неизвестный питомец", 2);
        genericAnimal.DisplayInfo();
        genericAnimal.MakeSound();
        Console.WriteLine("\n--------------------\n");

        Console.WriteLine("Нажмите любую клавишу для выхода...");
// Out:
// --- Создание и использование животных ---
// --- Информация о животном (Собака) ---
// Имя: Бадди
// Возраст: 5 лет
// Порода: Золотистый ретривер
// Бадди говорит: Гав! Гав!
//
// --------------------
//
// --- Информация о животном (Кошка) ---
// Имя: Пушинка
// Возраст: 3 лет
// Цвет шерсти: Рыжий
// Пушинка говорит: Мяу!
//
// --------------------
//
// --- Информация о животном (Птица) ---
// Имя: Кеша
// Возраст: 1 лет
// Может летать: Да
// Кеша говорит: Чирик-чирик!
//
// --------------------
//
// --- Информация о животном (Неизвестное животное) ---
// Имя: Неизвестный питомец
// Возраст: 2 лет
// Неизвестный питомец издает общий животный звук.
//
// --------------------
//
// Нажмите любую клавишу для выхода...
